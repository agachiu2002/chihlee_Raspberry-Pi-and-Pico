# %%
#list--- for in 迴圈
#"明確知道要執行幾次" 用for in 迴圈
total = 0
for i in range (1, 1001): #1000個 頭尾不算
    total += i
total
# Out:
# 500500

# %%
#不知道執行次數-用 while 迴圈
#while +Bool (布林值)
#範例
score = 0
time_left = 10 # 初始時間 (秒)
target_score = 50

# 複雜的條件表達式：只要「時間大於 0」且「分數還未達到目標」，迴圈就繼續
while time_left > 0 and score < target_score:
    print(f"--- 遊戲狀態 --- 時間: {time_left}s, 分數: {score}")
    
    # 模擬遊戲運行
    # 1. 時間減少
    time_left -= 1
    
    # 2. 隨機增加分數（簡化為每次加 10）
    score += 10
    
    # 註：在實際應用中，您可能需要 time.sleep(1) 來模擬真實時間
    
print("\n--- 遊戲結束 ---")

# 檢查是哪個條件導致迴圈終止
if time_left <= 0:
    print(f"⌛ 遊戲結束：時間耗盡！最終分數: {score}")
elif score >= target_score:
    print(f"🏆 遊戲結束：恭喜您，達成目標分數 {target_score}！")

# 輸出結果 (時間先耗盡)：
# --- 遊戲狀態 --- 時間: 10s, 分數: 0
# --- 遊戲狀態 --- 時間: 9s, 分數: 10
# ... (中間省略)
# --- 遊戲狀態 --- 時間: 1s, 分數: 90
#
# --- 遊戲結束 ---
# 🏆 遊戲結束：恭喜您，達成目標分數 50！ 
# (在這個例子中，score 很快達標 50，所以是 score >= target_score 讓迴圈提早結束)
# Out:
# --- 遊戲狀態 --- 時間: 10s, 分數: 0
# --- 遊戲狀態 --- 時間: 9s, 分數: 10
# --- 遊戲狀態 --- 時間: 8s, 分數: 20
# --- 遊戲狀態 --- 時間: 7s, 分數: 30
# --- 遊戲狀態 --- 時間: 6s, 分數: 40
#
# --- 遊戲結束 ---
# 🏆 遊戲結束：恭喜您，達成目標分數 50！

# %%
import random

while random.randint(1,10)  !=5:
    print("不等於5")
print("等於5")
# Out:
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 不等於5
# 等於5

# %%
import random

while True:
    if random.randint(1,10) ==5:
        break
    print ("不是5")

print("等於5")
# Out:
# 不是5
# 不是5
# 不是5
# 不是5
# 不是5
# 等於5
